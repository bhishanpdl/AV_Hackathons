# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Description" data-toc-modified-id="Description-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Description</a></span></li><li><span><a href="#Load-the-libraries" data-toc-modified-id="Load-the-libraries-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load the libraries</a></span></li><li><span><a href="#Load-the-data" data-toc-modified-id="Load-the-data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Load the data</a></span></li><li><span><a href="#Data-Processing" data-toc-modified-id="Data-Processing-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Data Processing</a></span></li><li><span><a href="#Modelling" data-toc-modified-id="Modelling-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Modelling</a></span><ul class="toc-item"><li><span><a href="#Train-validation-split" data-toc-modified-id="Train-validation-split-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Train validation split</a></span></li><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Logistic Regression</a></span></li><li><span><a href="#SGD-Classifier" data-toc-modified-id="SGD-Classifier-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>SGD Classifier</a></span></li><li><span><a href="#SVC" data-toc-modified-id="SVC-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>SVC</a></span></li><li><span><a href="#Gaussina-Naive-Bias" data-toc-modified-id="Gaussina-Naive-Bias-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Gaussina Naive Bias</a></span></li><li><span><a href="#LDA-linear-discriminant-analysis" data-toc-modified-id="LDA-linear-discriminant-analysis-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>LDA linear discriminant analysis</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Random Forest</a></span></li><li><span><a href="#Extra-Trees" data-toc-modified-id="Extra-Trees-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Extra Trees</a></span></li><li><span><a href="#AdaBoost" data-toc-modified-id="AdaBoost-5.9"><span class="toc-item-num">5.9&nbsp;&nbsp;</span>AdaBoost</a></span></li><li><span><a href="#GradientBoosting-Classifier" data-toc-modified-id="GradientBoosting-Classifier-5.10"><span class="toc-item-num">5.10&nbsp;&nbsp;</span>GradientBoosting Classifier</a></span></li><li><span><a href="#Xgboost" data-toc-modified-id="Xgboost-5.11"><span class="toc-item-num">5.11&nbsp;&nbsp;</span>Xgboost</a></span></li><li><span><a href="#Lightgbm" data-toc-modified-id="Lightgbm-5.12"><span class="toc-item-num">5.12&nbsp;&nbsp;</span>Lightgbm</a></span></li><li><span><a href="#Catboost" data-toc-modified-id="Catboost-5.13"><span class="toc-item-num">5.13&nbsp;&nbsp;</span>Catboost</a></span></li><li><span><a href="#Voting-Classifier" data-toc-modified-id="Voting-Classifier-5.14"><span class="toc-item-num">5.14&nbsp;&nbsp;</span>Voting Classifier</a></span></li><li><span><a href="#Stacking-Classifier" data-toc-modified-id="Stacking-Classifier-5.15"><span class="toc-item-num">5.15&nbsp;&nbsp;</span>Stacking Classifier</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Description
# Reference: https://datahack.analyticsvidhya.com/contest/all/
#
#
# **Predict Loan Eligibility for Dream Housing Finance company**
# Dream Housing Finance company deals in all kinds of home loans. They have presence across all urban, semi urban and rural areas. Customer first applies for home loan and after that company validates the customer eligibility for loan.
#
# Company wants to automate the loan eligibility process (real time) based on customer detail provided while filling online application form. These details are Gender, Marital Status, Education, Number of Dependents, Income, Loan Amount, Credit History and others. To automate this process, they have provided a dataset to identify the customers segments that are eligible for loan amount so that they can specifically target these customers.
#
# **Data Dictionary**
# Train file: CSV containing the customers for whom loan eligibility is known as 'Loan_Status'
#
# | Variable | Description |
# | :---|:---|
# | Loan_ID | Unique Loan ID |
# | Gender | Male/ Female |
# | Married | Applicant married (Y/N) |
# | Dependents | Number of dependents |
# | Education | Applicant Education (Graduate/ Under Graduate) |
# | Self_Employed | Self employed (Y/N) |
# | ApplicantIncome | Applicant income |
# | CoapplicantIncome | Coapplicant income |
# | LoanAmount | Loan amount in thousands |
# | Loan_Amount_Term | Term of loan in months |
# | Credit_History | credit history meets guidelines |
# | Property_Area | Urban/ Semi Urban/ Rural |
# | Loan_Status | (Target) Loan approved (Y/N) |
#
#
# **Evaluation Metric**
# Your model performance will be evaluated on the basis of your prediction of loan status for the test data (test.csv), which contains similar data-points as train except for the loan status to be predicted. Your submission needs to be in the format as shown in sample submission.
#
# We at our end, have the actual loan status for the test dataset, against which your predictions will be evaluated. We will use the Accuracy value to judge your response.
#
#
#
# **Public and Private Split**
# Test file is further divided into Public (25%) and Private (75%)
#
# Your initial responses will be checked and scored on the Public data.
# The final rankings would be based on your private score which will be published once the competition is over.

# %% [markdown]
# # Load the libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns

pd.set_option('max_columns',100)
pd.set_option('max_colwidth',500)
SEED=100

# %%
import sklearn
import xgboost

[(x.__name__,x.__version__) for x in [sklearn,xgboost]]
# Out:
# [('sklearn', '0.23.1'), ('xgboost', '1.1.1')]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

from xgboost import XGBClassifier

from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import StackingClassifier

# %% [markdown]
# # Load the data

# %%
df_train = pd.read_csv('../data/raw/train.csv')
print(df_train.shape)
df_train.head()
# Out:
# (614, 13)
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df_test = pd.read_csv('../data/raw/test.csv')
print(df_test.shape)
df_test.head()
# Out:
# (367, 12)
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# 3             NaN         Urban
# 4             1.0         Urban

# %% [markdown]
# # Data Processing

# %%
def clean_data(df):
    df = df.copy()
    # drop unwanted features
    df = df.drop('Loan_ID',axis=1)

    # missing values imputation
    ## fill married yes no from graudated or not
    cond = (df['Education']=='Graduate') & (df['Married'].isnull()) 
    df.loc[cond, 'Married'] = 'Yes'
    cond = (df['Education']!='Graduate') & (df['Married'].isnull()) 
    df.loc[cond, 'Married'] = 'No'

    ## fill with mode
    cols_mode = ['Gender', 'Dependents', 'Self_Employed', 'Credit_History']
    for c in cols_mode:
        df[c] = df[c].fillna(df[c].mode()[0])

    ## fill with mean
    cols_mean = ['LoanAmount','Loan_Amount_Term' ]
    for c in cols_mean:
        df[c] = df[c].fillna(df[c].mean())

    # mapping string to integers
    df['Gender'] = df['Gender'].map({'Male':1, 'Female': 0})
    df['Married'] = df['Married'].map({'Yes':1, 'No': 0 })
    df['Education'] = df['Education'].map({'Graduate': 1, 'Not Graduate': 0})
    df['Self_Employed'] = df['Self_Employed'].map({'Yes':1, 'No': 0})
    
    # target 
    target = 'Loan_Status'
    if target in df.columns:
        df[target] = df[target].map({'Y':1, 'N': 0})

    # one hot encoding
    cols = ['Dependents','Property_Area']
    df = pd.get_dummies(df,columns=cols,drop_first=True)
    return df

# %%
df_train = pd.read_csv('../data/raw/train.csv')
df_test = pd.read_csv('../data/raw/test.csv')

df_train = clean_data(df_train)
df_test = clean_data(df_test)

print(df_train.shape)
print(df_test.shape)
df_train.head(2).append(df_train.tail(2))
# Out:
# (614, 15)
# (367, 14)
#      Gender  Married  Education  Self_Employed  ApplicantIncome  \
# 0         1        0          1              0             5849
# 1         1        1          1              0             4583
# 612       1        1          1              0             7583
# 613       0        0          1              1             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0  146.412162             360.0             1.0
# 1               1508.0  128.000000             360.0             1.0
# 612                0.0  187.000000             360.0             1.0
# 613                0.0  133.000000             360.0             0.0
#
#      Loan_Status  Dependents_1  Dependents_2  Dependents_3+  \
# 0              1             0             0              0
# 1              0             1             0              0
# 612            1             0             1              0
# 613            0             0             0              0
#
#      Property_Area_Semiurban  Property_Area_Urban
# 0                          0                    1
# 1                          0                    0
# 612                        0                    1
# 613                        1                    0

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Train validation split

# %%
from sklearn.model_selection import train_test_split

# %%
df_train_orig = df_train.copy()
target = 'Loan_Status'
df_Xtrain, df_Xvalid, ser_ytrain, ser_yvalid = train_test_split(
    df_train_orig.drop(target,axis=1), df_train_orig[target],
    test_size = 0.2,
    random_state=SEED,
    stratify=df_train_orig[target]
)

ytrain = ser_ytrain.to_numpy().ravel()
yvalid = ser_yvalid.to_numpy().ravel()

print(f'train shape: {df_Xtrain.shape}')
print(f'valid shape: {df_Xvalid.shape}')

df_Xtrain.head(2)
# Out:
# train shape: (491, 14)
# valid shape: (123, 14)
#      Gender  Married  Education  Self_Employed  ApplicantIncome  \
# 203       1        1          0              0             3500
# 369       1        1          1              0            19730
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 203             1083.0       135.0             360.0             1.0
# 369             5266.0       570.0             360.0             1.0
#
#      Dependents_1  Dependents_2  Dependents_3+  Property_Area_Semiurban  \
# 203             1             0              0                        0
# 369             0             0              0                        0
#
#      Property_Area_Urban
# 203                    1
# 369                    0

# %%
Xtr = df_Xtrain
ytr = ytrain
Xvd = df_Xvalid
yvd = yvalid

# %%
from sklearn import metrics

df_eval = pd.DataFrame({
    'Model': [],
    'Description': [],
    'Accuracy': [],
    'Precision': [],
    'Recall': [],
    'F-score': [],
    'Time_Taken': [],
})

# %%
TREE_METHOD =  'auto'
print(TREE_METHOD)
# Out:
# auto

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
import time

# %%
scaler = StandardScaler()
Xtr_sc = scaler.fit_transform(Xtr)

# %%
time_start = time.time()
model = LogisticRegression(random_state=SEED,max_iter=10_000)
model.fit(Xtr,ytr)

vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['Logreg', 'default', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_21a2073a_e650_11ea_841d_8c859004fb9crow0_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_21a2073a_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_21a2073a_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_21a2073a_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_21a2073a_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >Logreg</td>
#                         <td id="T_21a2073a_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default</td>
#                         <td id="T_21a2073a_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.821138</td>
#                         <td id="T_21a2073a_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.800000</td>
#                         <td id="T_21a2073a_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_21a2073a_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.884211</td>
#                         <td id="T_21a2073a_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.04 s</td>
#             </tr>
#     </tbody></table>

# %%
time_start = time.time()
model = LogisticRegression(random_state=SEED,max_iter=10_000)
model.fit(Xtr_sc,ytr)

vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['Logreg', 'scaled', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_21a7ab22_e650_11ea_841d_8c859004fb9crow0_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_21a7ab22_e650_11ea_841d_8c859004fb9crow1_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_21a7ab22_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_21a7ab22_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_21a7ab22_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_21a7ab22_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >Logreg</td>
#                         <td id="T_21a7ab22_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default</td>
#                         <td id="T_21a7ab22_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.821138</td>
#                         <td id="T_21a7ab22_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.800000</td>
#                         <td id="T_21a7ab22_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_21a7ab22_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.884211</td>
#                         <td id="T_21a7ab22_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21a7ab22_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_21a7ab22_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >1</td>
#                         <td id="T_21a7ab22_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >Logreg</td>
#                         <td id="T_21a7ab22_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >scaled</td>
#                         <td id="T_21a7ab22_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.552846</td>
#                         <td id="T_21a7ab22_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.663043</td>
#                         <td id="T_21a7ab22_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >0.717647</td>
#                         <td id="T_21a7ab22_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.689266</td>
#                         <td id="T_21a7ab22_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.01 s</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## SGD Classifier

# %%
from sklearn.linear_model import SGDClassifier
# SGDClassifier?

# %%
time_start = time.time()
model = SGDClassifier(random_state=SEED,n_jobs=-1)
model.fit(Xtr,ytr)

vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['sgd', 'default', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_21ae486a_e650_11ea_841d_8c859004fb9crow0_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_21ae486a_e650_11ea_841d_8c859004fb9crow1_col3{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_21ae486a_e650_11ea_841d_8c859004fb9crow2_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_21ae486a_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_21ae486a_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >Logreg</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.821138</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.800000</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.884211</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21ae486a_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >2</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >sgd</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >default</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.691057</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.691057</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >1.000000</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.817308</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21ae486a_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >1</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >Logreg</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >scaled</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.552846</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.663043</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >0.717647</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.689266</td>
#                         <td id="T_21ae486a_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.01 s</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## SVC

# %%
from sklearn.svm import SVC

# SVC?

# %%
time_start = time.time()
model = SVC(random_state=SEED)
model.fit(Xtr,ytr)

vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['svc', 'default', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_21b5bc58_e650_11ea_841d_8c859004fb9crow0_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_21b5bc58_e650_11ea_841d_8c859004fb9crow1_col3,#T_21b5bc58_e650_11ea_841d_8c859004fb9crow2_col3{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_21b5bc58_e650_11ea_841d_8c859004fb9crow3_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_21b5bc58_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_21b5bc58_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >Logreg</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.821138</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.800000</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.884211</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21b5bc58_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >2</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >sgd</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >default</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.691057</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.691057</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >1.000000</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.817308</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21b5bc58_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >3</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >svc</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >default</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.691057</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.691057</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >1.000000</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.817308</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.02 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21b5bc58_e650_11ea_841d_8c859004fb9clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow3_col0" class="data row3 col0" >1</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow3_col1" class="data row3 col1" >Logreg</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow3_col2" class="data row3 col2" >scaled</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow3_col3" class="data row3 col3" >0.552846</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow3_col4" class="data row3 col4" >0.663043</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow3_col5" class="data row3 col5" >0.717647</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow3_col6" class="data row3 col6" >0.689266</td>
#                         <td id="T_21b5bc58_e650_11ea_841d_8c859004fb9crow3_col7" class="data row3 col7" >0 min 0.01 s</td>
#             </tr>
#     </tbody></table>

# %%
time_start = time.time()
model = SVC(random_state=SEED)
model.fit(Xtr_sc,ytr)

vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['svc', 'scaled', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_21bc3a10_e650_11ea_841d_8c859004fb9crow0_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_21bc3a10_e650_11ea_841d_8c859004fb9crow1_col3,#T_21bc3a10_e650_11ea_841d_8c859004fb9crow2_col3,#T_21bc3a10_e650_11ea_841d_8c859004fb9crow3_col3{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_21bc3a10_e650_11ea_841d_8c859004fb9crow4_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_21bc3a10_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_21bc3a10_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >Logreg</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.821138</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.800000</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.884211</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21bc3a10_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >2</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >sgd</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >default</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.691057</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.691057</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >1.000000</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.817308</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21bc3a10_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >3</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >svc</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >default</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.691057</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.691057</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >1.000000</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.817308</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.02 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21bc3a10_e650_11ea_841d_8c859004fb9clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow3_col0" class="data row3 col0" >4</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow3_col1" class="data row3 col1" >svc</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow3_col2" class="data row3 col2" >scaled</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow3_col3" class="data row3 col3" >0.691057</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow3_col4" class="data row3 col4" >0.691057</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow3_col5" class="data row3 col5" >1.000000</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow3_col6" class="data row3 col6" >0.817308</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow3_col7" class="data row3 col7" >0 min 0.02 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21bc3a10_e650_11ea_841d_8c859004fb9clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow4_col0" class="data row4 col0" >1</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow4_col1" class="data row4 col1" >Logreg</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow4_col2" class="data row4 col2" >scaled</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow4_col3" class="data row4 col3" >0.552846</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow4_col4" class="data row4 col4" >0.663043</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow4_col5" class="data row4 col5" >0.717647</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow4_col6" class="data row4 col6" >0.689266</td>
#                         <td id="T_21bc3a10_e650_11ea_841d_8c859004fb9crow4_col7" class="data row4 col7" >0 min 0.01 s</td>
#             </tr>
#     </tbody></table>

# %%
time_start = time.time()
model = SVC(random_state=SEED,kernel='linear')
model.fit(Xtr_sc,ytr)

vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['svc', 'linear', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_21c1ba4e_e650_11ea_841d_8c859004fb9crow0_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_21c1ba4e_e650_11ea_841d_8c859004fb9crow1_col3{
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }#T_21c1ba4e_e650_11ea_841d_8c859004fb9crow2_col3,#T_21c1ba4e_e650_11ea_841d_8c859004fb9crow3_col3,#T_21c1ba4e_e650_11ea_841d_8c859004fb9crow4_col3{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_21c1ba4e_e650_11ea_841d_8c859004fb9crow5_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_21c1ba4e_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_21c1ba4e_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >Logreg</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.821138</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.800000</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.884211</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21c1ba4e_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >5</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >svc</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >linear</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.699187</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.696721</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >1.000000</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.821256</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21c1ba4e_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >2</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >sgd</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >default</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.691057</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.691057</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >1.000000</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.817308</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21c1ba4e_e650_11ea_841d_8c859004fb9clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow3_col0" class="data row3 col0" >3</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow3_col1" class="data row3 col1" >svc</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow3_col2" class="data row3 col2" >default</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow3_col3" class="data row3 col3" >0.691057</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow3_col4" class="data row3 col4" >0.691057</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow3_col5" class="data row3 col5" >1.000000</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow3_col6" class="data row3 col6" >0.817308</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow3_col7" class="data row3 col7" >0 min 0.02 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21c1ba4e_e650_11ea_841d_8c859004fb9clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow4_col0" class="data row4 col0" >4</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow4_col1" class="data row4 col1" >svc</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow4_col2" class="data row4 col2" >scaled</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow4_col3" class="data row4 col3" >0.691057</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow4_col4" class="data row4 col4" >0.691057</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow4_col5" class="data row4 col5" >1.000000</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow4_col6" class="data row4 col6" >0.817308</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow4_col7" class="data row4 col7" >0 min 0.02 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21c1ba4e_e650_11ea_841d_8c859004fb9clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow5_col0" class="data row5 col0" >1</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow5_col1" class="data row5 col1" >Logreg</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow5_col2" class="data row5 col2" >scaled</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow5_col3" class="data row5 col3" >0.552846</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow5_col4" class="data row5 col4" >0.663043</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow5_col5" class="data row5 col5" >0.717647</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow5_col6" class="data row5 col6" >0.689266</td>
#                         <td id="T_21c1ba4e_e650_11ea_841d_8c859004fb9crow5_col7" class="data row5 col7" >0 min 0.01 s</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Gaussina Naive Bias

# %%
from sklearn.naive_bayes import GaussianNB

# GaussianNB?

# %%
time_start = time.time()
model = GaussianNB()
model.fit(Xtr,ytr)

vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['gnb', 'default', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_21c885a4_e650_11ea_841d_8c859004fb9crow0_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_21c885a4_e650_11ea_841d_8c859004fb9crow1_col3{
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }#T_21c885a4_e650_11ea_841d_8c859004fb9crow2_col3{
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }#T_21c885a4_e650_11ea_841d_8c859004fb9crow3_col3,#T_21c885a4_e650_11ea_841d_8c859004fb9crow4_col3,#T_21c885a4_e650_11ea_841d_8c859004fb9crow5_col3{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_21c885a4_e650_11ea_841d_8c859004fb9crow6_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_21c885a4_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_21c885a4_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >Logreg</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.821138</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.800000</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.884211</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21c885a4_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >6</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >gnb</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >default</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.788618</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.804124</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >0.917647</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.857143</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21c885a4_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >5</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >svc</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >linear</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.699187</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.696721</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >1.000000</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.821256</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21c885a4_e650_11ea_841d_8c859004fb9clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow3_col0" class="data row3 col0" >2</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow3_col1" class="data row3 col1" >sgd</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow3_col2" class="data row3 col2" >default</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow3_col3" class="data row3 col3" >0.691057</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow3_col4" class="data row3 col4" >0.691057</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow3_col5" class="data row3 col5" >1.000000</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow3_col6" class="data row3 col6" >0.817308</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow3_col7" class="data row3 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21c885a4_e650_11ea_841d_8c859004fb9clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow4_col0" class="data row4 col0" >3</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow4_col1" class="data row4 col1" >svc</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow4_col2" class="data row4 col2" >default</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow4_col3" class="data row4 col3" >0.691057</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow4_col4" class="data row4 col4" >0.691057</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow4_col5" class="data row4 col5" >1.000000</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow4_col6" class="data row4 col6" >0.817308</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow4_col7" class="data row4 col7" >0 min 0.02 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21c885a4_e650_11ea_841d_8c859004fb9clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow5_col0" class="data row5 col0" >4</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow5_col1" class="data row5 col1" >svc</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow5_col2" class="data row5 col2" >scaled</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow5_col3" class="data row5 col3" >0.691057</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow5_col4" class="data row5 col4" >0.691057</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow5_col5" class="data row5 col5" >1.000000</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow5_col6" class="data row5 col6" >0.817308</td>
#                         <td id="T_21c885a4_e650_11ea_841d_8c859004fb9crow5_col7" class="data row5 col7" >0 min 0.02 s</td>
#             </tr>
#             <tr>

# %% [markdown]
# ## LDA linear discriminant analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# LDA?

# %%
time_start = time.time()
model = LDA()
model.fit(Xtr,ytr)

vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['lda', 'default', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_21cf74fe_e650_11ea_841d_8c859004fb9crow0_col3,#T_21cf74fe_e650_11ea_841d_8c859004fb9crow1_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_21cf74fe_e650_11ea_841d_8c859004fb9crow2_col3{
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }#T_21cf74fe_e650_11ea_841d_8c859004fb9crow3_col3{
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }#T_21cf74fe_e650_11ea_841d_8c859004fb9crow4_col3,#T_21cf74fe_e650_11ea_841d_8c859004fb9crow5_col3,#T_21cf74fe_e650_11ea_841d_8c859004fb9crow6_col3{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_21cf74fe_e650_11ea_841d_8c859004fb9crow7_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_21cf74fe_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_21cf74fe_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >Logreg</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.821138</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.800000</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.884211</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21cf74fe_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >7</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >lda</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >default</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.821138</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.800000</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >0.988235</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.884211</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21cf74fe_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >6</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >gnb</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >default</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.788618</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.804124</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >0.917647</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.857143</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21cf74fe_e650_11ea_841d_8c859004fb9clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow3_col0" class="data row3 col0" >5</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow3_col1" class="data row3 col1" >svc</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow3_col2" class="data row3 col2" >linear</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow3_col3" class="data row3 col3" >0.699187</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow3_col4" class="data row3 col4" >0.696721</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow3_col5" class="data row3 col5" >1.000000</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow3_col6" class="data row3 col6" >0.821256</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow3_col7" class="data row3 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21cf74fe_e650_11ea_841d_8c859004fb9clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow4_col0" class="data row4 col0" >2</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow4_col1" class="data row4 col1" >sgd</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow4_col2" class="data row4 col2" >default</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow4_col3" class="data row4 col3" >0.691057</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow4_col4" class="data row4 col4" >0.691057</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow4_col5" class="data row4 col5" >1.000000</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow4_col6" class="data row4 col6" >0.817308</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow4_col7" class="data row4 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_21cf74fe_e650_11ea_841d_8c859004fb9clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow5_col0" class="data row5 col0" >3</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow5_col1" class="data row5 col1" >svc</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow5_col2" class="data row5 col2" >default</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow5_col3" class="data row5 col3" >0.691057</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow5_col4" class="data row5 col4" >0.691057</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow5_col5" class="data row5 col5" >1.000000</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow5_col6" class="data row5 col6" >0.817308</td>
#                         <td id="T_21cf74fe_e650_11ea_841d_8c859004fb9crow5_col7" class="data row5 col7" >0 min 0.02

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
time_start = time.time()
model = RandomForestClassifier(n_jobs=-1,random_state=SEED)
model.fit(Xtr,ytr)

vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['rf', 'default', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_220e480a_e650_11ea_841d_8c859004fb9crow0_col3,#T_220e480a_e650_11ea_841d_8c859004fb9crow1_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_220e480a_e650_11ea_841d_8c859004fb9crow2_col3{
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }#T_220e480a_e650_11ea_841d_8c859004fb9crow3_col3{
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }#T_220e480a_e650_11ea_841d_8c859004fb9crow4_col3{
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }#T_220e480a_e650_11ea_841d_8c859004fb9crow5_col3,#T_220e480a_e650_11ea_841d_8c859004fb9crow6_col3,#T_220e480a_e650_11ea_841d_8c859004fb9crow7_col3{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_220e480a_e650_11ea_841d_8c859004fb9crow8_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_220e480a_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_220e480a_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >Logreg</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.821138</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.800000</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.884211</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_220e480a_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >7</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >lda</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >default</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.821138</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.800000</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >0.988235</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.884211</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_220e480a_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >8</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >rf</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >default</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.813008</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.803922</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >0.964706</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.877005</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.37 s</td>
#             </tr>
#             <tr>
#                         <th id="T_220e480a_e650_11ea_841d_8c859004fb9clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow3_col0" class="data row3 col0" >6</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow3_col1" class="data row3 col1" >gnb</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow3_col2" class="data row3 col2" >default</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow3_col3" class="data row3 col3" >0.788618</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow3_col4" class="data row3 col4" >0.804124</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow3_col5" class="data row3 col5" >0.917647</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow3_col6" class="data row3 col6" >0.857143</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow3_col7" class="data row3 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_220e480a_e650_11ea_841d_8c859004fb9clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow4_col0" class="data row4 col0" >5</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow4_col1" class="data row4 col1" >svc</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow4_col2" class="data row4 col2" >linear</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow4_col3" class="data row4 col3" >0.699187</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow4_col4" class="data row4 col4" >0.696721</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow4_col5" class="data row4 col5" >1.000000</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow4_col6" class="data row4 col6" >0.821256</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow4_col7" class="data row4 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_220e480a_e650_11ea_841d_8c859004fb9clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow5_col0" class="data row5 col0" >2</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow5_col1" class="data row5 col1" >sgd</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow5_col2" class="data row5 col2" >default</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow5_col3" class="data row5 col3" >0.691057</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow5_col4" class="data row5 col4" >0.691057</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow5_col5" class="data row5 col5" >1.000000</td>
#                         <td id="T_220e480a_e650_11ea_841d_8c859004fb9crow5_col6" class="data row5 col6" >0.8

# %%
time_start = time.time()
model = RandomForestClassifier(n_estimators=500, n_jobs=-1,random_state=SEED)
model.fit(Xtr,ytr)

vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['rf', 'n_estimators=500', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_229fbca4_e650_11ea_841d_8c859004fb9crow0_col3,#T_229fbca4_e650_11ea_841d_8c859004fb9crow1_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_229fbca4_e650_11ea_841d_8c859004fb9crow2_col3{
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }#T_229fbca4_e650_11ea_841d_8c859004fb9crow3_col3{
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }#T_229fbca4_e650_11ea_841d_8c859004fb9crow4_col3{
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }#T_229fbca4_e650_11ea_841d_8c859004fb9crow5_col3{
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }#T_229fbca4_e650_11ea_841d_8c859004fb9crow6_col3,#T_229fbca4_e650_11ea_841d_8c859004fb9crow7_col3,#T_229fbca4_e650_11ea_841d_8c859004fb9crow8_col3{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_229fbca4_e650_11ea_841d_8c859004fb9crow9_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_229fbca4_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_229fbca4_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >Logreg</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.821138</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.800000</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.884211</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_229fbca4_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >7</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >lda</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >default</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.821138</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.800000</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >0.988235</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.884211</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_229fbca4_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >8</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >rf</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >default</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.813008</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.803922</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >0.964706</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.877005</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.37 s</td>
#             </tr>
#             <tr>
#                         <th id="T_229fbca4_e650_11ea_841d_8c859004fb9clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow3_col0" class="data row3 col0" >9</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow3_col1" class="data row3 col1" >rf</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow3_col2" class="data row3 col2" >n_estimators=500</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow3_col3" class="data row3 col3" >0.804878</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow3_col4" class="data row3 col4" >0.796117</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow3_col5" class="data row3 col5" >0.964706</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow3_col6" class="data row3 col6" >0.872340</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow3_col7" class="data row3 col7" >0 min 0.93 s</td>
#             </tr>
#             <tr>
#                         <th id="T_229fbca4_e650_11ea_841d_8c859004fb9clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow4_col0" class="data row4 col0" >6</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow4_col1" class="data row4 col1" >gnb</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow4_col2" class="data row4 col2" >default</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow4_col3" class="data row4 col3" >0.788618</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow4_col4" class="data row4 col4" >0.804124</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow4_col5" class="data row4 col5" >0.917647</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow4_col6" class="data row4 col6" >0.857143</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow4_col7" class="data row4 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_229fbca4_e650_11ea_841d_8c859004fb9clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow5_col0" class="data row5 col0" >5</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow5_col1" class="data row5 col1" >svc</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow5_col2" class="data row5 col2" >linear</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow5_col3" class="data row5 col3" >0.699187</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow5_col4" class="data row5 col4" >0.696721</td>
#                         <td id="T_229fbca4_e650_11ea_841d_8c859004fb9crow5_col5" class="dat

# %%
time_start = time.time()
params = {'bootstrap': False,
              'min_samples_leaf': 3,
              'n_estimators': 50,
              'min_samples_split': 10,
              'max_features': 'sqrt',
              'random_state': SEED,
              'n_jobs': -1,
              'max_depth': 6}

model = RandomForestClassifier(**params)
model.fit(Xtr,ytr)

vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['rf', 'tuned', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_22c74238_e650_11ea_841d_8c859004fb9crow0_col3,#T_22c74238_e650_11ea_841d_8c859004fb9crow1_col3,#T_22c74238_e650_11ea_841d_8c859004fb9crow2_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_22c74238_e650_11ea_841d_8c859004fb9crow3_col3{
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }#T_22c74238_e650_11ea_841d_8c859004fb9crow4_col3{
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }#T_22c74238_e650_11ea_841d_8c859004fb9crow5_col3{
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }#T_22c74238_e650_11ea_841d_8c859004fb9crow6_col3{
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }#T_22c74238_e650_11ea_841d_8c859004fb9crow7_col3,#T_22c74238_e650_11ea_841d_8c859004fb9crow8_col3,#T_22c74238_e650_11ea_841d_8c859004fb9crow9_col3{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_22c74238_e650_11ea_841d_8c859004fb9crow10_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_22c74238_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_22c74238_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >Logreg</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.821138</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.800000</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.884211</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_22c74238_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >7</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >lda</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >default</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.821138</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.800000</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >0.988235</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.884211</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_22c74238_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >10</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >rf</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >tuned</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.821138</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.800000</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >0.988235</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.884211</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.23 s</td>
#             </tr>
#             <tr>
#                         <th id="T_22c74238_e650_11ea_841d_8c859004fb9clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow3_col0" class="data row3 col0" >8</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow3_col1" class="data row3 col1" >rf</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow3_col2" class="data row3 col2" >default</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow3_col3" class="data row3 col3" >0.813008</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow3_col4" class="data row3 col4" >0.803922</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow3_col5" class="data row3 col5" >0.964706</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow3_col6" class="data row3 col6" >0.877005</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow3_col7" class="data row3 col7" >0 min 0.37 s</td>
#             </tr>
#             <tr>
#                         <th id="T_22c74238_e650_11ea_841d_8c859004fb9clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow4_col0" class="data row4 col0" >9</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow4_col1" class="data row4 col1" >rf</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow4_col2" class="data row4 col2" >n_estimators=500</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow4_col3" class="data row4 col3" >0.804878</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow4_col4" class="data row4 col4" >0.796117</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow4_col5" class="data row4 col5" >0.964706</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow4_col6" class="data row4 col6" >0.872340</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow4_col7" class="data row4 col7" >0 min 0.93 s</td>
#             </tr>
#             <tr>
#                         <th id="T_22c74238_e650_11ea_841d_8c859004fb9clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow5_col0" class="data row5 col0" >6</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow5_col1" class="data row5 col1" >gnb</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow5_col2" class="data row5 col2" >default</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow5_col3" class="data row5 col3" >0.788618</td>
#                         <td id="T_22c74238_e650_11ea_841d_8c859004fb9crow5_col4" class="data row5 col4" >0.804124</td>
#                         <td id="T_22c74238

# %% [markdown]
# ## Extra Trees

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
time_start = time.time()
model = ExtraTreesClassifier(bootstrap=True,
                             criterion='entropy', max_features=0.8,
                             min_samples_leaf=19,
                             min_samples_split=5, n_estimators=100)
model.fit(Xtr,ytr)

vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['extratrees', 'tuned', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_22e63dc8_e650_11ea_841d_8c859004fb9crow0_col3,#T_22e63dc8_e650_11ea_841d_8c859004fb9crow1_col3,#T_22e63dc8_e650_11ea_841d_8c859004fb9crow2_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_22e63dc8_e650_11ea_841d_8c859004fb9crow3_col3,#T_22e63dc8_e650_11ea_841d_8c859004fb9crow4_col3{
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }#T_22e63dc8_e650_11ea_841d_8c859004fb9crow5_col3{
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }#T_22e63dc8_e650_11ea_841d_8c859004fb9crow6_col3{
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }#T_22e63dc8_e650_11ea_841d_8c859004fb9crow7_col3{
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }#T_22e63dc8_e650_11ea_841d_8c859004fb9crow8_col3,#T_22e63dc8_e650_11ea_841d_8c859004fb9crow9_col3,#T_22e63dc8_e650_11ea_841d_8c859004fb9crow10_col3{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_22e63dc8_e650_11ea_841d_8c859004fb9crow11_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_22e63dc8_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_22e63dc8_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >Logreg</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.821138</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.800000</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.884211</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_22e63dc8_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >7</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >lda</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >default</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.821138</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.800000</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >0.988235</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.884211</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_22e63dc8_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >10</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >rf</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >tuned</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.821138</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.800000</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >0.988235</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.884211</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.23 s</td>
#             </tr>
#             <tr>
#                         <th id="T_22e63dc8_e650_11ea_841d_8c859004fb9clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow3_col0" class="data row3 col0" >8</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow3_col1" class="data row3 col1" >rf</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow3_col2" class="data row3 col2" >default</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow3_col3" class="data row3 col3" >0.813008</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow3_col4" class="data row3 col4" >0.803922</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow3_col5" class="data row3 col5" >0.964706</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow3_col6" class="data row3 col6" >0.877005</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow3_col7" class="data row3 col7" >0 min 0.37 s</td>
#             </tr>
#             <tr>
#                         <th id="T_22e63dc8_e650_11ea_841d_8c859004fb9clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow4_col0" class="data row4 col0" >11</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow4_col1" class="data row4 col1" >extratrees</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow4_col2" class="data row4 col2" >tuned</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow4_col3" class="data row4 col3" >0.813008</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow4_col4" class="data row4 col4" >0.792453</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow4_col5" class="data row4 col5" >0.988235</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow4_col6" class="data row4 col6" >0.879581</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow4_col7" class="data row4 col7" >0 min 0.17 s</td>
#             </tr>
#             <tr>
#                         <th id="T_22e63dc8_e650_11ea_841d_8c859004fb9clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow5_col0" class="data row5 col0" >9</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow5_col1" class="data row5 col1" >rf</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow5_col2" class="data row5 col2" >n_estimators=500</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow5_col3" class="data row5 col3" >0.804878</td>
#                         <td id="T_22e63dc8_e650_11ea_841d_8c859004fb9crow5_col4" class="data row5 col4" >

# %% [markdown]
# ## AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

# AdaBoostClassifier?

# %%
time_start = time.time()
model = AdaBoostClassifier(random_state=SEED)
model.fit(Xtr,ytr)

vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['ada', 'default', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_22f8e57c_e650_11ea_841d_8c859004fb9crow0_col3,#T_22f8e57c_e650_11ea_841d_8c859004fb9crow1_col3,#T_22f8e57c_e650_11ea_841d_8c859004fb9crow2_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_22f8e57c_e650_11ea_841d_8c859004fb9crow3_col3,#T_22f8e57c_e650_11ea_841d_8c859004fb9crow4_col3,#T_22f8e57c_e650_11ea_841d_8c859004fb9crow5_col3{
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }#T_22f8e57c_e650_11ea_841d_8c859004fb9crow6_col3{
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }#T_22f8e57c_e650_11ea_841d_8c859004fb9crow7_col3{
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }#T_22f8e57c_e650_11ea_841d_8c859004fb9crow8_col3{
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }#T_22f8e57c_e650_11ea_841d_8c859004fb9crow9_col3,#T_22f8e57c_e650_11ea_841d_8c859004fb9crow10_col3,#T_22f8e57c_e650_11ea_841d_8c859004fb9crow11_col3{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_22f8e57c_e650_11ea_841d_8c859004fb9crow12_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_22f8e57c_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_22f8e57c_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >Logreg</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.821138</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.800000</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.884211</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_22f8e57c_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >7</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >lda</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >default</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.821138</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.800000</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >0.988235</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.884211</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_22f8e57c_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >10</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >rf</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >tuned</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.821138</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.800000</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >0.988235</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.884211</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.23 s</td>
#             </tr>
#             <tr>
#                         <th id="T_22f8e57c_e650_11ea_841d_8c859004fb9clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow3_col0" class="data row3 col0" >8</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow3_col1" class="data row3 col1" >rf</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow3_col2" class="data row3 col2" >default</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow3_col3" class="data row3 col3" >0.813008</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow3_col4" class="data row3 col4" >0.803922</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow3_col5" class="data row3 col5" >0.964706</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow3_col6" class="data row3 col6" >0.877005</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow3_col7" class="data row3 col7" >0 min 0.37 s</td>
#             </tr>
#             <tr>
#                         <th id="T_22f8e57c_e650_11ea_841d_8c859004fb9clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow4_col0" class="data row4 col0" >11</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow4_col1" class="data row4 col1" >extratrees</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow4_col2" class="data row4 col2" >tuned</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow4_col3" class="data row4 col3" >0.813008</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow4_col4" class="data row4 col4" >0.792453</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow4_col5" class="data row4 col5" >0.988235</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow4_col6" class="data row4 col6" >0.879581</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow4_col7" class="data row4 col7" >0 min 0.17 s</td>
#             </tr>
#             <tr>
#                         <th id="T_22f8e57c_e650_11ea_841d_8c859004fb9clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow5_col0" class="data row5 col0" >12</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow5_col1" class="data row5 col1" >ada</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow5_col2" class="data row5 col2" >default</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c859004fb9crow5_col3" class="data row5 col3" >0.813008</td>
#                         <td id="T_22f8e57c_e650_11ea_841d_8c85

# %% [markdown]
# ## GradientBoosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
time_start = time.time()
model = GradientBoostingClassifier(random_state= SEED)
model.fit(Xtr,ytr)

vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['gb', 'default', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_230d8fb8_e650_11ea_841d_8c859004fb9crow0_col3,#T_230d8fb8_e650_11ea_841d_8c859004fb9crow1_col3,#T_230d8fb8_e650_11ea_841d_8c859004fb9crow2_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_230d8fb8_e650_11ea_841d_8c859004fb9crow3_col3,#T_230d8fb8_e650_11ea_841d_8c859004fb9crow4_col3,#T_230d8fb8_e650_11ea_841d_8c859004fb9crow5_col3{
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }#T_230d8fb8_e650_11ea_841d_8c859004fb9crow6_col3{
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }#T_230d8fb8_e650_11ea_841d_8c859004fb9crow7_col3{
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }#T_230d8fb8_e650_11ea_841d_8c859004fb9crow8_col3{
#             background-color:  #04649d;
#             color:  #f1f1f1;
#         }#T_230d8fb8_e650_11ea_841d_8c859004fb9crow9_col3{
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }#T_230d8fb8_e650_11ea_841d_8c859004fb9crow10_col3,#T_230d8fb8_e650_11ea_841d_8c859004fb9crow11_col3,#T_230d8fb8_e650_11ea_841d_8c859004fb9crow12_col3{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_230d8fb8_e650_11ea_841d_8c859004fb9crow13_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_230d8fb8_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_230d8fb8_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >Logreg</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.821138</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.800000</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.884211</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_230d8fb8_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >7</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >lda</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >default</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.821138</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.800000</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >0.988235</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.884211</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_230d8fb8_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >10</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >rf</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >tuned</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.821138</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.800000</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >0.988235</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.884211</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.23 s</td>
#             </tr>
#             <tr>
#                         <th id="T_230d8fb8_e650_11ea_841d_8c859004fb9clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow3_col0" class="data row3 col0" >8</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow3_col1" class="data row3 col1" >rf</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow3_col2" class="data row3 col2" >default</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow3_col3" class="data row3 col3" >0.813008</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow3_col4" class="data row3 col4" >0.803922</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow3_col5" class="data row3 col5" >0.964706</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow3_col6" class="data row3 col6" >0.877005</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow3_col7" class="data row3 col7" >0 min 0.37 s</td>
#             </tr>
#             <tr>
#                         <th id="T_230d8fb8_e650_11ea_841d_8c859004fb9clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow4_col0" class="data row4 col0" >11</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow4_col1" class="data row4 col1" >extratrees</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow4_col2" class="data row4 col2" >tuned</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow4_col3" class="data row4 col3" >0.813008</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow4_col4" class="data row4 col4" >0.792453</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow4_col5" class="data row4 col5" >0.988235</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow4_col6" class="data row4 col6" >0.879581</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow4_col7" class="data row4 col7" >0 min 0.17 s</td>
#             </tr>
#             <tr>
#                         <th id="T_230d8fb8_e650_11ea_841d_8c859004fb9clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow5_col0" class="data row5 col0" >12</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow5_col1" class="data row5 col1" >ada</td>
#                         <td id="T_230d8fb8_e650_11ea_841d_8c859004fb9crow5_col2" class="data row5 col2" >default</td>
#                         <td id="T_230d8fb8_e650_11ea

# %%
time_start = time.time()
params = {'min_samples_leaf': 17,
          'max_features': 0.95,
          'max_depth': 3,
          'learning_rate': 0.03,
          'n_estimators': 500,
         'random_state': SEED}

model = GradientBoostingClassifier(**params)
model.fit(Xtr,ytr)

vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['gb', 'tuned', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_234dbe76_e650_11ea_841d_8c859004fb9crow0_col3,#T_234dbe76_e650_11ea_841d_8c859004fb9crow1_col3,#T_234dbe76_e650_11ea_841d_8c859004fb9crow2_col3,#T_234dbe76_e650_11ea_841d_8c859004fb9crow3_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_234dbe76_e650_11ea_841d_8c859004fb9crow4_col3,#T_234dbe76_e650_11ea_841d_8c859004fb9crow5_col3,#T_234dbe76_e650_11ea_841d_8c859004fb9crow6_col3{
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }#T_234dbe76_e650_11ea_841d_8c859004fb9crow7_col3{
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }#T_234dbe76_e650_11ea_841d_8c859004fb9crow8_col3{
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }#T_234dbe76_e650_11ea_841d_8c859004fb9crow9_col3{
#             background-color:  #04649d;
#             color:  #f1f1f1;
#         }#T_234dbe76_e650_11ea_841d_8c859004fb9crow10_col3{
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }#T_234dbe76_e650_11ea_841d_8c859004fb9crow11_col3,#T_234dbe76_e650_11ea_841d_8c859004fb9crow12_col3,#T_234dbe76_e650_11ea_841d_8c859004fb9crow13_col3{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_234dbe76_e650_11ea_841d_8c859004fb9crow14_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_234dbe76_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_234dbe76_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >Logreg</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.821138</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.800000</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.884211</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_234dbe76_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >7</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >lda</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >default</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.821138</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.800000</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >0.988235</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.884211</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_234dbe76_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >10</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >rf</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >tuned</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.821138</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.800000</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >0.988235</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.884211</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.23 s</td>
#             </tr>
#             <tr>
#                         <th id="T_234dbe76_e650_11ea_841d_8c859004fb9clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow3_col0" class="data row3 col0" >14</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow3_col1" class="data row3 col1" >gb</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow3_col2" class="data row3 col2" >tuned</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow3_col3" class="data row3 col3" >0.821138</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow3_col4" class="data row3 col4" >0.811881</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow3_col5" class="data row3 col5" >0.964706</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow3_col6" class="data row3 col6" >0.881720</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow3_col7" class="data row3 col7" >0 min 0.39 s</td>
#             </tr>
#             <tr>
#                         <th id="T_234dbe76_e650_11ea_841d_8c859004fb9clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow4_col0" class="data row4 col0" >8</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow4_col1" class="data row4 col1" >rf</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow4_col2" class="data row4 col2" >default</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow4_col3" class="data row4 col3" >0.813008</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow4_col4" class="data row4 col4" >0.803922</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow4_col5" class="data row4 col5" >0.964706</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow4_col6" class="data row4 col6" >0.877005</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow4_col7" class="data row4 col7" >0 min 0.37 s</td>
#             </tr>
#             <tr>
#                         <th id="T_234dbe76_e650_11ea_841d_8c859004fb9clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow5_col0" class="data row5 col0" >11</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow5_col1" class="data row5 col1" >extratrees</td>
#                         <td id="T_234dbe76_e650_11ea_841d_8c859004fb9crow5_col2" class="data row5 col2" >tuned</td>

# %% [markdown]
# ## Xgboost
# Note: default xgboost 0.9 gives accuracy 0.82
# but defautl xgboost 1.1.1 gives accuracy 0.78.
# They changed the default parameters.

# %%
import xgboost
from xgboost import XGBClassifier

xgboost.__version__
# Out:
# '1.1.1'

# %%
time_start = time.time()
model = XGBClassifier(random_state=SEED,n_jobs=-1)

model.fit(Xtr,ytr)
vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['xgb', 'default', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_23621844_e650_11ea_841d_8c859004fb9crow0_col3,#T_23621844_e650_11ea_841d_8c859004fb9crow1_col3,#T_23621844_e650_11ea_841d_8c859004fb9crow2_col3,#T_23621844_e650_11ea_841d_8c859004fb9crow3_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_23621844_e650_11ea_841d_8c859004fb9crow4_col3,#T_23621844_e650_11ea_841d_8c859004fb9crow5_col3,#T_23621844_e650_11ea_841d_8c859004fb9crow6_col3{
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }#T_23621844_e650_11ea_841d_8c859004fb9crow7_col3{
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }#T_23621844_e650_11ea_841d_8c859004fb9crow8_col3{
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }#T_23621844_e650_11ea_841d_8c859004fb9crow9_col3{
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }#T_23621844_e650_11ea_841d_8c859004fb9crow10_col3{
#             background-color:  #04649d;
#             color:  #f1f1f1;
#         }#T_23621844_e650_11ea_841d_8c859004fb9crow11_col3{
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }#T_23621844_e650_11ea_841d_8c859004fb9crow12_col3,#T_23621844_e650_11ea_841d_8c859004fb9crow13_col3,#T_23621844_e650_11ea_841d_8c859004fb9crow14_col3{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_23621844_e650_11ea_841d_8c859004fb9crow15_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_23621844_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_23621844_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >Logreg</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.821138</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.800000</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.884211</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_23621844_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >7</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >lda</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >default</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.821138</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.800000</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >0.988235</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.884211</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_23621844_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >10</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >rf</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >tuned</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.821138</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.800000</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >0.988235</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.884211</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.23 s</td>
#             </tr>
#             <tr>
#                         <th id="T_23621844_e650_11ea_841d_8c859004fb9clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow3_col0" class="data row3 col0" >14</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow3_col1" class="data row3 col1" >gb</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow3_col2" class="data row3 col2" >tuned</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow3_col3" class="data row3 col3" >0.821138</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow3_col4" class="data row3 col4" >0.811881</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow3_col5" class="data row3 col5" >0.964706</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow3_col6" class="data row3 col6" >0.881720</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow3_col7" class="data row3 col7" >0 min 0.39 s</td>
#             </tr>
#             <tr>
#                         <th id="T_23621844_e650_11ea_841d_8c859004fb9clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow4_col0" class="data row4 col0" >8</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow4_col1" class="data row4 col1" >rf</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow4_col2" class="data row4 col2" >default</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow4_col3" class="data row4 col3" >0.813008</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow4_col4" class="data row4 col4" >0.803922</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow4_col5" class="data row4 col5" >0.964706</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow4_col6" class="data row4 col6" >0.877005</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow4_col7" class="data row4 col7" >0 min 0.37 s</td>
#             </tr>
#             <tr>
#                         <th id="T_23621844_e650_11ea_841d_8c859004fb9clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow5_col0" class="data row5 col0" >11</td>
#                         <td id="T_23621844_e650_11ea_841d_8c859004fb9crow5_col1" class="data row5 col1" >extratre

# %%
time_start = time.time()
model = XGBClassifier(n_estimators=100, random_state=SEED,n_jobs=-1)

model.fit(Xtr,ytr)
vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['xgb', 'n_estimators=100', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_2373c760_e650_11ea_841d_8c859004fb9crow0_col3,#T_2373c760_e650_11ea_841d_8c859004fb9crow1_col3,#T_2373c760_e650_11ea_841d_8c859004fb9crow2_col3,#T_2373c760_e650_11ea_841d_8c859004fb9crow3_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_2373c760_e650_11ea_841d_8c859004fb9crow4_col3,#T_2373c760_e650_11ea_841d_8c859004fb9crow5_col3,#T_2373c760_e650_11ea_841d_8c859004fb9crow6_col3{
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }#T_2373c760_e650_11ea_841d_8c859004fb9crow7_col3{
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }#T_2373c760_e650_11ea_841d_8c859004fb9crow8_col3{
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }#T_2373c760_e650_11ea_841d_8c859004fb9crow9_col3,#T_2373c760_e650_11ea_841d_8c859004fb9crow10_col3{
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }#T_2373c760_e650_11ea_841d_8c859004fb9crow11_col3{
#             background-color:  #04649d;
#             color:  #f1f1f1;
#         }#T_2373c760_e650_11ea_841d_8c859004fb9crow12_col3{
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }#T_2373c760_e650_11ea_841d_8c859004fb9crow13_col3,#T_2373c760_e650_11ea_841d_8c859004fb9crow14_col3,#T_2373c760_e650_11ea_841d_8c859004fb9crow15_col3{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_2373c760_e650_11ea_841d_8c859004fb9crow16_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_2373c760_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2373c760_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >Logreg</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.821138</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.800000</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.884211</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_2373c760_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >7</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >lda</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >default</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.821138</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.800000</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >0.988235</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.884211</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_2373c760_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >14</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >gb</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >tuned</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.821138</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.811881</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >0.964706</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.881720</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.39 s</td>
#             </tr>
#             <tr>
#                         <th id="T_2373c760_e650_11ea_841d_8c859004fb9clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow3_col0" class="data row3 col0" >10</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow3_col1" class="data row3 col1" >rf</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow3_col2" class="data row3 col2" >tuned</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow3_col3" class="data row3 col3" >0.821138</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow3_col4" class="data row3 col4" >0.800000</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow3_col5" class="data row3 col5" >0.988235</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow3_col6" class="data row3 col6" >0.884211</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow3_col7" class="data row3 col7" >0 min 0.23 s</td>
#             </tr>
#             <tr>
#                         <th id="T_2373c760_e650_11ea_841d_8c859004fb9clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow4_col0" class="data row4 col0" >12</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow4_col1" class="data row4 col1" >ada</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow4_col2" class="data row4 col2" >default</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow4_col3" class="data row4 col3" >0.813008</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow4_col4" class="data row4 col4" >0.798077</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow4_col5" class="data row4 col5" >0.976471</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow4_col6" class="data row4 col6" >0.878307</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow4_col7" class="data row4 col7" >0 min 0.09 s</td>
#             </tr>
#             <tr>
#                         <th id="T_2373c760_e650_11ea_841d_8c859004fb9clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_2373c760_e650_11ea_841d_8c859004fb9crow5_col0" class="data row5 col0" >11</td>
#                         <td id="T_2373c760_e650_11ea_841d_8c8

# %%
time_start = time.time()
# default from xgboost version 0.9
model = XGBClassifier(
    # always same
    tree_method=TREE_METHOD,
    objective='binary:logistic',
    random_state=100,
    n_jobs=-1,
    verbosity=1,
    base_score=0.5,

    # most imp
    n_estimators=100,
    learning_rate=0.1,

    # subsample and colsample
    subsample=1,
    colsample_bylevel=1,
    colsample_bynode=1, 
    colsample_bytree=1,

    # tree depth
    max_depth=3,
    min_child_weight=1,
    scale_pos_weight=1,
    
    # regularizaion alpha lambda gamma
    reg_alpha=0,
    reg_lambda=1,
    gamma=0,
    )

model.fit(Xtr,ytr)
vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['xgb', 'default_xgb0.9', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_23808d42_e650_11ea_841d_8c859004fb9crow0_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_23808d42_e650_11ea_841d_8c859004fb9crow1_col3,#T_23808d42_e650_11ea_841d_8c859004fb9crow2_col3,#T_23808d42_e650_11ea_841d_8c859004fb9crow3_col3,#T_23808d42_e650_11ea_841d_8c859004fb9crow4_col3{
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }#T_23808d42_e650_11ea_841d_8c859004fb9crow5_col3,#T_23808d42_e650_11ea_841d_8c859004fb9crow6_col3,#T_23808d42_e650_11ea_841d_8c859004fb9crow7_col3{
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }#T_23808d42_e650_11ea_841d_8c859004fb9crow8_col3{
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }#T_23808d42_e650_11ea_841d_8c859004fb9crow9_col3{
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }#T_23808d42_e650_11ea_841d_8c859004fb9crow10_col3,#T_23808d42_e650_11ea_841d_8c859004fb9crow11_col3{
#             background-color:  #04639b;
#             color:  #f1f1f1;
#         }#T_23808d42_e650_11ea_841d_8c859004fb9crow12_col3{
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }#T_23808d42_e650_11ea_841d_8c859004fb9crow13_col3{
#             background-color:  #65a3cb;
#             color:  #000000;
#         }#T_23808d42_e650_11ea_841d_8c859004fb9crow14_col3,#T_23808d42_e650_11ea_841d_8c859004fb9crow15_col3,#T_23808d42_e650_11ea_841d_8c859004fb9crow16_col3{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_23808d42_e650_11ea_841d_8c859004fb9crow17_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_23808d42_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_23808d42_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >17</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >xgb</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default_xgb0.9</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.829268</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.807692</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.888889</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.05 s</td>
#             </tr>
#             <tr>
#                         <th id="T_23808d42_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >7</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >lda</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >default</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.821138</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.800000</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >0.988235</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.884211</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_23808d42_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >14</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >gb</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >tuned</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.821138</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.811881</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >0.964706</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.881720</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.39 s</td>
#             </tr>
#             <tr>
#                         <th id="T_23808d42_e650_11ea_841d_8c859004fb9clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow3_col0" class="data row3 col0" >10</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow3_col1" class="data row3 col1" >rf</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow3_col2" class="data row3 col2" >tuned</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow3_col3" class="data row3 col3" >0.821138</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow3_col4" class="data row3 col4" >0.800000</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow3_col5" class="data row3 col5" >0.988235</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow3_col6" class="data row3 col6" >0.884211</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow3_col7" class="data row3 col7" >0 min 0.23 s</td>
#             </tr>
#             <tr>
#                         <th id="T_23808d42_e650_11ea_841d_8c859004fb9clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow4_col0" class="data row4 col0" >0</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow4_col1" class="data row4 col1" >Logreg</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow4_col2" class="data row4 col2" >default</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow4_col3" class="data row4 col3" >0.821138</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow4_col4" class="data row4 col4" >0.800000</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow4_col5" class="data row4 col5" >0.988235</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow4_col6" class="data row4 col6" >0.884211</td>
#                         <td id="T_23808d42_e650_11ea_841d_8c859004fb9crow4_col7" class="data row4 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_23808d42_e650_11ea_841d_8c859004fb9clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_2380

# %%
time_start = time.time()
model = XGBClassifier(learning_rate =0.1, n_estimators=1000, max_depth=8, min_child_weight=6, gamma=0.1, subsample=0.95,
                     colsample_bytree=0.95, reg_alpha=2,
                      objective= 'binary:logistic', nthread=4, 
                      scale_pos_weight=1, seed=SEED)

model.fit(Xtr,ytr)
vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['xgb', 'tuned2', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_23bdd620_e650_11ea_841d_8c859004fb9crow0_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_23bdd620_e650_11ea_841d_8c859004fb9crow1_col3,#T_23bdd620_e650_11ea_841d_8c859004fb9crow2_col3,#T_23bdd620_e650_11ea_841d_8c859004fb9crow3_col3,#T_23bdd620_e650_11ea_841d_8c859004fb9crow4_col3{
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }#T_23bdd620_e650_11ea_841d_8c859004fb9crow5_col3,#T_23bdd620_e650_11ea_841d_8c859004fb9crow6_col3,#T_23bdd620_e650_11ea_841d_8c859004fb9crow7_col3{
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }#T_23bdd620_e650_11ea_841d_8c859004fb9crow8_col3{
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }#T_23bdd620_e650_11ea_841d_8c859004fb9crow9_col3{
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }#T_23bdd620_e650_11ea_841d_8c859004fb9crow10_col3,#T_23bdd620_e650_11ea_841d_8c859004fb9crow11_col3,#T_23bdd620_e650_11ea_841d_8c859004fb9crow12_col3{
#             background-color:  #04639b;
#             color:  #f1f1f1;
#         }#T_23bdd620_e650_11ea_841d_8c859004fb9crow13_col3{
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }#T_23bdd620_e650_11ea_841d_8c859004fb9crow14_col3{
#             background-color:  #65a3cb;
#             color:  #000000;
#         }#T_23bdd620_e650_11ea_841d_8c859004fb9crow15_col3,#T_23bdd620_e650_11ea_841d_8c859004fb9crow16_col3,#T_23bdd620_e650_11ea_841d_8c859004fb9crow17_col3{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_23bdd620_e650_11ea_841d_8c859004fb9crow18_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_23bdd620_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_23bdd620_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >17</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >xgb</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default_xgb0.9</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.829268</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.807692</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.888889</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.05 s</td>
#             </tr>
#             <tr>
#                         <th id="T_23bdd620_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >0</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >Logreg</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >default</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.821138</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.800000</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >0.988235</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.884211</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_23bdd620_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >14</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >gb</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >tuned</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.821138</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.811881</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >0.964706</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.881720</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.39 s</td>
#             </tr>
#             <tr>
#                         <th id="T_23bdd620_e650_11ea_841d_8c859004fb9clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow3_col0" class="data row3 col0" >10</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow3_col1" class="data row3 col1" >rf</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow3_col2" class="data row3 col2" >tuned</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow3_col3" class="data row3 col3" >0.821138</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow3_col4" class="data row3 col4" >0.800000</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow3_col5" class="data row3 col5" >0.988235</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow3_col6" class="data row3 col6" >0.884211</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow3_col7" class="data row3 col7" >0 min 0.23 s</td>
#             </tr>
#             <tr>
#                         <th id="T_23bdd620_e650_11ea_841d_8c859004fb9clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow4_col0" class="data row4 col0" >7</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow4_col1" class="data row4 col1" >lda</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow4_col2" class="data row4 col2" >default</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow4_col3" class="data row4 col3" >0.821138</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow4_col4" class="data row4 col4" >0.800000</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow4_col5" class="data row4 col5" >0.988235</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow4_col6" class="data row4 col6" >0.884211</td>
#                         <td id="T_23bdd620_e650_11ea_841d_8c859004fb9crow4_col7" class="data row4 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_23bdd620_e650_11ea_841d_8c859004fb9clevel0_row5" class="row_heading level0 ro

# %% [markdown]
# ## Lightgbm

# %%
from lightgbm import LGBMClassifier

# %%
time_start = time.time()
model = LGBMClassifier(random_state=SEED,n_jobs=-1)

model.fit(Xtr,ytr)
vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['lgb', 'default', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_23d3cc78_e650_11ea_841d_8c859004fb9crow0_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_23d3cc78_e650_11ea_841d_8c859004fb9crow1_col3,#T_23d3cc78_e650_11ea_841d_8c859004fb9crow2_col3,#T_23d3cc78_e650_11ea_841d_8c859004fb9crow3_col3,#T_23d3cc78_e650_11ea_841d_8c859004fb9crow4_col3{
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }#T_23d3cc78_e650_11ea_841d_8c859004fb9crow5_col3,#T_23d3cc78_e650_11ea_841d_8c859004fb9crow6_col3,#T_23d3cc78_e650_11ea_841d_8c859004fb9crow7_col3{
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }#T_23d3cc78_e650_11ea_841d_8c859004fb9crow8_col3{
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }#T_23d3cc78_e650_11ea_841d_8c859004fb9crow9_col3{
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }#T_23d3cc78_e650_11ea_841d_8c859004fb9crow10_col3,#T_23d3cc78_e650_11ea_841d_8c859004fb9crow11_col3,#T_23d3cc78_e650_11ea_841d_8c859004fb9crow12_col3{
#             background-color:  #04639b;
#             color:  #f1f1f1;
#         }#T_23d3cc78_e650_11ea_841d_8c859004fb9crow13_col3{
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }#T_23d3cc78_e650_11ea_841d_8c859004fb9crow14_col3{
#             background-color:  #2182b9;
#             color:  #000000;
#         }#T_23d3cc78_e650_11ea_841d_8c859004fb9crow15_col3{
#             background-color:  #65a3cb;
#             color:  #000000;
#         }#T_23d3cc78_e650_11ea_841d_8c859004fb9crow16_col3,#T_23d3cc78_e650_11ea_841d_8c859004fb9crow17_col3,#T_23d3cc78_e650_11ea_841d_8c859004fb9crow18_col3{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_23d3cc78_e650_11ea_841d_8c859004fb9crow19_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_23d3cc78_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_23d3cc78_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >17</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >xgb</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default_xgb0.9</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.829268</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.807692</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.888889</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.05 s</td>
#             </tr>
#             <tr>
#                         <th id="T_23d3cc78_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >0</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >Logreg</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >default</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.821138</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.800000</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >0.988235</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.884211</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_23d3cc78_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >7</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >lda</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >default</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.821138</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.800000</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >0.988235</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.884211</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_23d3cc78_e650_11ea_841d_8c859004fb9clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow3_col0" class="data row3 col0" >14</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow3_col1" class="data row3 col1" >gb</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow3_col2" class="data row3 col2" >tuned</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow3_col3" class="data row3 col3" >0.821138</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow3_col4" class="data row3 col4" >0.811881</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow3_col5" class="data row3 col5" >0.964706</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow3_col6" class="data row3 col6" >0.881720</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow3_col7" class="data row3 col7" >0 min 0.39 s</td>
#             </tr>
#             <tr>
#                         <th id="T_23d3cc78_e650_11ea_841d_8c859004fb9clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow4_col0" class="data row4 col0" >10</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow4_col1" class="data row4 col1" >rf</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow4_col2" class="data row4 col2" >tuned</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow4_col3" class="data row4 col3" >0.821138</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow4_col4" class="data row4 col4" >0.800000</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow4_col5" class="data row4 col5" >0.988235</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow4_col6" class="data row4 col6" >0.884211</td>
#                         <td id="T_23d3cc78_e650_11ea_841d_8c859004fb9crow4_col7" class="data row4 col7" >0 min 0.23 s</td>
#             </tr>

# %% [markdown]
# ## Catboost

# %%
import catboost
from catboost import CatBoostClassifier

print(catboost.__version__)
# Out:
# 0.23.2

# %%
time_start = time.time()
model = CatBoostClassifier(random_state=SEED,verbose=0)

model.fit(Xtr,ytr)
vd_preds = model.predict(Xvd)

acc = metrics.accuracy_score(yvd, vd_preds)
pre = metrics.precision_score(yvd, vd_preds)
rec = metrics.recall_score(yvd, vd_preds)
f1  = metrics.f1_score(yvd,vd_preds)

time_taken = time.time() - time_start
time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

row = ['cb', 'default', acc, pre, rec, f1,time_taken]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# <style  type="text/css" >
# #T_24b5fe18_e650_11ea_841d_8c859004fb9crow0_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_24b5fe18_e650_11ea_841d_8c859004fb9crow1_col3,#T_24b5fe18_e650_11ea_841d_8c859004fb9crow2_col3,#T_24b5fe18_e650_11ea_841d_8c859004fb9crow3_col3,#T_24b5fe18_e650_11ea_841d_8c859004fb9crow4_col3{
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }#T_24b5fe18_e650_11ea_841d_8c859004fb9crow5_col3,#T_24b5fe18_e650_11ea_841d_8c859004fb9crow6_col3,#T_24b5fe18_e650_11ea_841d_8c859004fb9crow7_col3,#T_24b5fe18_e650_11ea_841d_8c859004fb9crow8_col3{
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }#T_24b5fe18_e650_11ea_841d_8c859004fb9crow9_col3{
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }#T_24b5fe18_e650_11ea_841d_8c859004fb9crow10_col3{
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }#T_24b5fe18_e650_11ea_841d_8c859004fb9crow11_col3,#T_24b5fe18_e650_11ea_841d_8c859004fb9crow12_col3,#T_24b5fe18_e650_11ea_841d_8c859004fb9crow13_col3{
#             background-color:  #04639b;
#             color:  #f1f1f1;
#         }#T_24b5fe18_e650_11ea_841d_8c859004fb9crow14_col3{
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }#T_24b5fe18_e650_11ea_841d_8c859004fb9crow15_col3{
#             background-color:  #2182b9;
#             color:  #000000;
#         }#T_24b5fe18_e650_11ea_841d_8c859004fb9crow16_col3{
#             background-color:  #65a3cb;
#             color:  #000000;
#         }#T_24b5fe18_e650_11ea_841d_8c859004fb9crow17_col3,#T_24b5fe18_e650_11ea_841d_8c859004fb9crow18_col3,#T_24b5fe18_e650_11ea_841d_8c859004fb9crow19_col3{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_24b5fe18_e650_11ea_841d_8c859004fb9crow20_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_24b5fe18_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_24b5fe18_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >17</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >xgb</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default_xgb0.9</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.829268</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.807692</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.888889</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.05 s</td>
#             </tr>
#             <tr>
#                         <th id="T_24b5fe18_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >0</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >Logreg</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >default</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.821138</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.800000</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >0.988235</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.884211</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_24b5fe18_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >7</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >lda</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >default</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.821138</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.800000</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >0.988235</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.884211</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_24b5fe18_e650_11ea_841d_8c859004fb9clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow3_col0" class="data row3 col0" >14</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow3_col1" class="data row3 col1" >gb</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow3_col2" class="data row3 col2" >tuned</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow3_col3" class="data row3 col3" >0.821138</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow3_col4" class="data row3 col4" >0.811881</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow3_col5" class="data row3 col5" >0.964706</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow3_col6" class="data row3 col6" >0.881720</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow3_col7" class="data row3 col7" >0 min 0.39 s</td>
#             </tr>
#             <tr>
#                         <th id="T_24b5fe18_e650_11ea_841d_8c859004fb9clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow4_col0" class="data row4 col0" >10</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow4_col1" class="data row4 col1" >rf</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow4_col2" class="data row4 col2" >tuned</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow4_col3" class="data row4 col3" >0.821138</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow4_col4" class="data row4 col4" >0.800000</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow4_col5" class="data row4 col5" >0.988235</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow4_col6" class="data row4 col6" >0.884211</td>
#                         <td id="T_24b5fe18_e650_11ea_841d_8c859004fb9crow4_col7" class="da

# %% [markdown]
# ## Voting Classifier

# %%
from sklearn.ensemble import VotingClassifier

# %%
# %%time

time_start = time.time()
params_rf = {'bootstrap': False,
              'min_samples_leaf': 3,
              'n_estimators': 50,
              'min_samples_split': 10,
              'max_features': 'sqrt',
              'random_state': SEED,
              'n_jobs': -1,
              'max_depth': 6}

params_xgb = dict(
    # always same
    tree_method=TREE_METHOD,
    objective='binary:logistic',
    random_state=100,
    n_jobs=-1,
    verbosity=1,
    base_score=0.5,

    # most imp
    n_estimators=100,
    learning_rate=0.1,

    # subsample and colsample
    subsample=1,
    colsample_bylevel=1,
    colsample_bynode=1, 
    colsample_bytree=1,

    # tree depth
    max_depth=3,
    min_child_weight=1,
    scale_pos_weight=1,
    
    # regularizaion alpha lambda gamma
    reg_alpha=0,
    reg_lambda=1,
    gamma=0,
)

clf_logr = LogisticRegression(random_state=SEED,max_iter=10_000)
clf_sgd = SGDClassifier(random_state=SEED,n_jobs=-1)
clf_svc = SVC(random_state=SEED,kernel='linear',probability=True)
clf_ada = AdaBoostClassifier(random_state=SEED)
clf_lda = LDA()
clf_rf = RandomForestClassifier(**params_rf)
clf_gb = GradientBoostingClassifier(random_state= SEED)
clf_xgb = XGBClassifier(**params_xgb)


model = VotingClassifier([
    ('logr',clf_logr),
    ('svc', clf_svc),
    ('rf', clf_rf),
    ('gb',clf_gb),
    ('xgb',clf_xgb)
    
    ],voting='soft')


# model.fit(Xtr,ytr)
# vd_preds = model.predict(Xvd)

# time_taken = time.time() - time_start
# time_taken = "{:.0f} min {:.2f} s".format(*divmod(time_taken,60))

# row = ['Logreg', 'default', acc, pre, rec, f1,time_taken]
# df_eval.loc[len(df_eval)] = row
# df_eval = df_eval.drop_duplicates(['Model','Description'])
# df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])

"""
CPU times: user 9min 59s, sys: 1.99 s, total: 10min 1s
Wall time: 10min 15s

18	voting	soft	0.821138	0.800000	0.988235	0.884211

xgb9 > logreg > lda > gbc > rf > VOTING
""";


row = ['voting', 'soft', 0.821138, 0.800000, 0.988235, 0.884211,"10 min 15 s"]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# CPU times: user 8.06 ms, sys: 1.24 ms, total: 9.3 ms
# Wall time: 9.37 ms
# <style  type="text/css" >
# #T_24bc9caa_e650_11ea_841d_8c859004fb9crow0_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_24bc9caa_e650_11ea_841d_8c859004fb9crow1_col3,#T_24bc9caa_e650_11ea_841d_8c859004fb9crow2_col3,#T_24bc9caa_e650_11ea_841d_8c859004fb9crow3_col3,#T_24bc9caa_e650_11ea_841d_8c859004fb9crow4_col3,#T_24bc9caa_e650_11ea_841d_8c859004fb9crow5_col3{
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }#T_24bc9caa_e650_11ea_841d_8c859004fb9crow6_col3,#T_24bc9caa_e650_11ea_841d_8c859004fb9crow7_col3,#T_24bc9caa_e650_11ea_841d_8c859004fb9crow8_col3,#T_24bc9caa_e650_11ea_841d_8c859004fb9crow9_col3{
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }#T_24bc9caa_e650_11ea_841d_8c859004fb9crow10_col3{
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }#T_24bc9caa_e650_11ea_841d_8c859004fb9crow11_col3{
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }#T_24bc9caa_e650_11ea_841d_8c859004fb9crow12_col3,#T_24bc9caa_e650_11ea_841d_8c859004fb9crow13_col3,#T_24bc9caa_e650_11ea_841d_8c859004fb9crow14_col3{
#             background-color:  #04639b;
#             color:  #f1f1f1;
#         }#T_24bc9caa_e650_11ea_841d_8c859004fb9crow15_col3{
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }#T_24bc9caa_e650_11ea_841d_8c859004fb9crow16_col3{
#             background-color:  #2182b9;
#             color:  #000000;
#         }#T_24bc9caa_e650_11ea_841d_8c859004fb9crow17_col3{
#             background-color:  #65a3cb;
#             color:  #000000;
#         }#T_24bc9caa_e650_11ea_841d_8c859004fb9crow18_col3,#T_24bc9caa_e650_11ea_841d_8c859004fb9crow19_col3,#T_24bc9caa_e650_11ea_841d_8c859004fb9crow20_col3{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_24bc9caa_e650_11ea_841d_8c859004fb9crow21_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_24bc9caa_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_24bc9caa_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >17</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >xgb</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default_xgb0.9</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.829268</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.807692</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.888889</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.05 s</td>
#             </tr>
#             <tr>
#                         <th id="T_24bc9caa_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >0</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >Logreg</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >default</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.821138</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.800000</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >0.988235</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.884211</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_24bc9caa_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >7</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >lda</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >default</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.821138</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.800000</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >0.988235</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.884211</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_24bc9caa_e650_11ea_841d_8c859004fb9clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow3_col0" class="data row3 col0" >14</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow3_col1" class="data row3 col1" >gb</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow3_col2" class="data row3 col2" >tuned</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow3_col3" class="data row3 col3" >0.821138</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow3_col4" class="data row3 col4" >0.811881</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow3_col5" class="data row3 col5" >0.964706</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow3_col6" class="data row3 col6" >0.881720</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow3_col7" class="data row3 col7" >0 min 0.39 s</td>
#             </tr>
#             <tr>
#                         <th id="T_24bc9caa_e650_11ea_841d_8c859004fb9clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow4_col0" class="data row4 col0" >10</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow4_col1" class="data row4 col1" >rf</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow4_col2" class="data row4 col2" >tuned</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow4_col3" class="data row4 col3" >0.821138</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow4_col4" class="data row4 col4" >0.800000</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow4_col5" class="data row4 col5" >0.988235</td>
#                         <td id="T_24bc9caa_e650_11ea_841d_8c859004fb9crow4_col6" class="data row4 col6" >0.884211</td>
#                         <td id="T_24bc9c

# %% [markdown]
# ## Stacking Classifier

# %%
from sklearn.ensemble import StackingClassifier

# %%
# %%time

time_start = time.time()
estimators = [
    ('svc', clf_svc),
    ('rf', clf_rf),
    ('gb',clf_gb),
    ('xgb',clf_xgb)
    
    ]

# model = StackingClassifier(estimators, final_estimator=clf_logr)

# model.fit(Xtr,ytr)
# vd_preds = model.predict(Xvd)

# acc = metrics.accuracy_score(yvd, vd_preds)
# pre = metrics.precision_score(yvd, vd_preds)
# rec = metrics.recall_score(yvd, vd_preds)
# f1  = metrics.f1_score(yvd,vd_preds)

# row = ['stacking', 'svc+rf+gb+xgb and final=logr', acc, pre, rec, f1]
# df_eval.loc[len(df_eval)] = row
# df_eval = df_eval.drop_duplicates(['Model','Description'])
# df_eval.sort_values('Accuracy',ascending=False)

"""

19	stacking	svc+rf+gb+xgb and final=logr	0.821138	0.800000	0.988235	0.884211


CPU times: user 56min, sys: 11 s, total: 56min 11s
Wall time: 57min 28s

""";

row = ['stacking', 'svc+rf+gb+xgb and final=logr', 0.821138, 0.800000, 0.988235, 0.884211,"56 min 11 s"]
df_eval.loc[len(df_eval)] = row
df_eval = df_eval.drop_duplicates(['Model','Description'])
df_eval.sort_values('Accuracy',ascending=False).reset_index().style.background_gradient(subset=['Accuracy'])
# Out:
# CPU times: user 10.5 ms, sys: 1.55 ms, total: 12 ms
# Wall time: 27.3 ms
# <style  type="text/css" >
# #T_24d50178_e650_11ea_841d_8c859004fb9crow0_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_24d50178_e650_11ea_841d_8c859004fb9crow1_col3,#T_24d50178_e650_11ea_841d_8c859004fb9crow2_col3,#T_24d50178_e650_11ea_841d_8c859004fb9crow3_col3,#T_24d50178_e650_11ea_841d_8c859004fb9crow4_col3,#T_24d50178_e650_11ea_841d_8c859004fb9crow5_col3,#T_24d50178_e650_11ea_841d_8c859004fb9crow6_col3{
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }#T_24d50178_e650_11ea_841d_8c859004fb9crow7_col3,#T_24d50178_e650_11ea_841d_8c859004fb9crow8_col3,#T_24d50178_e650_11ea_841d_8c859004fb9crow9_col3,#T_24d50178_e650_11ea_841d_8c859004fb9crow10_col3{
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }#T_24d50178_e650_11ea_841d_8c859004fb9crow11_col3{
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }#T_24d50178_e650_11ea_841d_8c859004fb9crow12_col3{
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }#T_24d50178_e650_11ea_841d_8c859004fb9crow13_col3,#T_24d50178_e650_11ea_841d_8c859004fb9crow14_col3,#T_24d50178_e650_11ea_841d_8c859004fb9crow15_col3{
#             background-color:  #04639b;
#             color:  #f1f1f1;
#         }#T_24d50178_e650_11ea_841d_8c859004fb9crow16_col3{
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }#T_24d50178_e650_11ea_841d_8c859004fb9crow17_col3{
#             background-color:  #2182b9;
#             color:  #000000;
#         }#T_24d50178_e650_11ea_841d_8c859004fb9crow18_col3{
#             background-color:  #65a3cb;
#             color:  #000000;
#         }#T_24d50178_e650_11ea_841d_8c859004fb9crow19_col3,#T_24d50178_e650_11ea_841d_8c859004fb9crow20_col3,#T_24d50178_e650_11ea_841d_8c859004fb9crow21_col3{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_24d50178_e650_11ea_841d_8c859004fb9crow22_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_24d50178_e650_11ea_841d_8c859004fb9c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Model</th>        <th class="col_heading level0 col2" >Description</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F-score</th>        <th class="col_heading level0 col7" >Time_Taken</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_24d50178_e650_11ea_841d_8c859004fb9clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow0_col0" class="data row0 col0" >17</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow0_col1" class="data row0 col1" >xgb</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow0_col2" class="data row0 col2" >default_xgb0.9</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow0_col3" class="data row0 col3" >0.829268</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow0_col4" class="data row0 col4" >0.807692</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow0_col5" class="data row0 col5" >0.988235</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow0_col6" class="data row0 col6" >0.888889</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow0_col7" class="data row0 col7" >0 min 0.05 s</td>
#             </tr>
#             <tr>
#                         <th id="T_24d50178_e650_11ea_841d_8c859004fb9clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow1_col0" class="data row1 col0" >0</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow1_col1" class="data row1 col1" >Logreg</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow1_col2" class="data row1 col2" >default</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow1_col3" class="data row1 col3" >0.821138</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow1_col4" class="data row1 col4" >0.800000</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow1_col5" class="data row1 col5" >0.988235</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow1_col6" class="data row1 col6" >0.884211</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow1_col7" class="data row1 col7" >0 min 0.04 s</td>
#             </tr>
#             <tr>
#                         <th id="T_24d50178_e650_11ea_841d_8c859004fb9clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow2_col0" class="data row2 col0" >7</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow2_col1" class="data row2 col1" >lda</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow2_col2" class="data row2 col2" >default</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow2_col3" class="data row2 col3" >0.821138</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow2_col4" class="data row2 col4" >0.800000</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow2_col5" class="data row2 col5" >0.988235</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow2_col6" class="data row2 col6" >0.884211</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow2_col7" class="data row2 col7" >0 min 0.01 s</td>
#             </tr>
#             <tr>
#                         <th id="T_24d50178_e650_11ea_841d_8c859004fb9clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow3_col0" class="data row3 col0" >14</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow3_col1" class="data row3 col1" >gb</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow3_col2" class="data row3 col2" >tuned</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow3_col3" class="data row3 col3" >0.821138</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow3_col4" class="data row3 col4" >0.811881</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow3_col5" class="data row3 col5" >0.964706</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow3_col6" class="data row3 col6" >0.881720</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow3_col7" class="data row3 col7" >0 min 0.39 s</td>
#             </tr>
#             <tr>
#                         <th id="T_24d50178_e650_11ea_841d_8c859004fb9clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow4_col0" class="data row4 col0" >10</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow4_col1" class="data row4 col1" >rf</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow4_col2" class="data row4 col2" >tuned</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow4_col3" class="data row4 col3" >0.821138</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow4_col4" class="data row4 col4" >0.800000</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow4_col5" class="data row4 col5" >0.988235</td>
#                         <td id="T_24d50178_e650_11ea_841d_8c859004fb9crow4_col6" class="data row4 col6" >0.88

# %%
df_eval.sort_values('Time_Taken',ascending=False)
# Out:
#          Model                   Description  Accuracy  Precision    Recall  \
# 22    stacking  svc+rf+gb+xgb and final=logr  0.821138   0.800000  0.988235
# 21      voting                          soft  0.821138   0.800000  0.988235
# 20          cb                       default  0.813008   0.798077  0.976471
# 9           rf              n_estimators=500  0.804878   0.796117  0.964706
# 14          gb                         tuned  0.821138   0.811881  0.964706
# 8           rf                       default  0.813008   0.803922  0.964706
# 18         xgb                        tuned2  0.780488   0.802083  0.905882
# 10          rf                         tuned  0.821138   0.800000  0.988235
# 11  extratrees                         tuned  0.813008   0.792453  0.988235
# 19         lgb                       default  0.739837   0.797753  0.835294
# 13          gb                       default  0.772358   0.787879  0.917647
# 12         ada                       default  0.813008   0.798077  0.976471
# 15         xgb                       default  0.780488   0.808511  0.894118
# 16         xgb              n_estimators=100  0.780488   0.808511  0.894118
# 17         xgb                default_xgb0.9  0.829268   0.807692  0.988235
# 0       Logreg                       default  0.821138   0.800000  0.988235
# 4          svc                        scaled  0.691057   0.691057  1.000000
# 3          svc                       default  0.691057   0.691057  1.000000
# 7          lda                       default  0.821138   0.800000  0.988235
# 6          gnb                       default  0.788618   0.804124  0.917647
# 1       Logreg                        scaled  0.552846   0.663043  0.717647
# 5          svc                        linear  0.699187   0.696721  1.000000
# 2          sgd                       default  0.691057   0.691057  1.000000
#
#      F-score    Time_Taken
# 22  0.884211   56 min 11 s
# 21  0.884211   10 min 15 s
# 20  0.878307  0 min 1.44 s
# 9   0.872340  0 min 0.93 s
# 14  0.881720  0 min 0.39 s
# 8   0.877005  0 min 0.37 s
# 18  0.850829  0 min 0.37 s
# 10  0.884211  0 min 0.23 s
# 11  0.879581  0 min 0.17 s
# 19  0.816092  0 min 0.11 s
# 13  0.847826  0 min 0.10 s
# 12  0.878307  0 min 0.09 s
# 15  0.849162  0 min 0.09 s
# 16  0.849162  0 min 0.09 s
# 17  0.888889  0 min 0.05 s
# 0   0.884211  0 min 0.04 s
# 4   0.817308  0 min 0.02 s
# 3   0.817308  0 min 0.02 s
# 7   0.884211  0 min 0.01 s
# 6   0.857143  0 min 0.01 s
# 1   0.689266  0 min 0.01 s
# 5   0.821256  0 min 0.01 s
# 2   0.817308  0 min 0.01 s
